# %% [markdown]
# # Time Series Prediction with Rössler Attractor inspired Deep Learning Model ($RAiDL$)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hampel in /usr/local/lib/python3.8/dist-packages (0.0.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from hampel) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from hampel) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->hampel) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.15.0)

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _El NINO_

# %%
data = pd.read_csv("/content/drive/MyDrive/new/datasets/elnino.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0       23.4
# 1       23.4
# 2       24.2
# 3       24.4
# 4       25.1
#         ...
# 1629    25.4
# 1630    24.9
# 1631    25.3
# 1632    24.7
# 1633    24.6
# Name: SST1, Length: 1634, dtype: float64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 29.2
# 1       0.000000
# 2       0.114286
# 3       0.028571
# 4       0.100000
# 5       0.100000
#           ...
# 1629   -0.242857
# 1630   -0.071429
# 1631    0.057143
# 1632   -0.085714
# 1633   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 2       1.632653e-02
# 3      -1.224490e-02
# 4       1.020408e-02
# 5      -7.335402e-17
# 6      -1.224490e-02
#             ...
# 1629   -2.857143e-02
# 1630    2.448980e-02
# 1631    1.836735e-02
# 1632   -2.040816e-02
# 1633    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0       0.000000
# 1       0.114286
# 2       0.028571
# 3       0.100000
# 4       0.100000
#           ...
# 1628   -0.242857
# 1629   -0.071429
# 1630    0.057143
# 1631   -0.085714
# 1632   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 0       1.632653e-02
# 1      -1.224490e-02
# 2       1.020408e-02
# 3      -7.335402e-17
# 4      -1.224490e-02
#             ...
# 1627   -2.857143e-02
# 1628    2.448980e-02
# 1629    1.836735e-02
# 1630   -2.040816e-02
# 1631    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (1633,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation

# %% [markdown]
# _Parameters_: $a=0.2\\$
# \\frac{dx}{dt} =-y\\
# \frac{dy}{dt} = x+ay$

# %%
a = 0.2
L = df.iloc[:, 2] + df.iloc[:, 0] - a*df.iloc[:, 1]
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)  # ,18,19
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        23.4       23.4       24.2       24.4       25.1       25.8
# 11        23.4       24.2       24.4       25.1       25.8       25.9
# 12        24.2       24.4       25.1       25.8       25.9       26.1
# 13        24.4       25.1       25.8       25.9       26.1       26.1
# 14        25.1       25.8       25.9       26.1       26.1       26.7
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10       25.9       26.1       26.1       26.7     26.1  0.000000 -0.008163
# 11       26.1       26.1       26.7       26.1     26.1 -0.057143  0.006122
# 12       26.1       26.7       26.1       26.1     25.7 -0.014286 -0.008163
# 13       26.7       26.1       26.1       25.7     25.6 -0.071429  0.014286
# 14       26.1       26.1       25.7       25.6     25.1  0.028571 -0.008163
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1622, 13)
# (1622, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1297, 1, 10) (1297, 3) (325, 1, 10) (325, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.2, name="a", trainable=True, dtype=tf.float32)

def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 0] - a*y_true[:, 1]), (y_pred[:, 2] + y_pred[:, 0] - a*y_pred[:, 1]))


def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + y_pred[:-2] -a*(y_pred[1:-1]-y_pred[:-2])
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + y_real[:-2] -a*(y_real[1:-1]-y_real[:-2])
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($RAiDL$)

# %%
a = tf.Variable(0.2, name="a", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] + y_pred[:, 0] - a*y_pred[:, 1])
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)
model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 21/21 - 3s - loss: 0.1088 - val_loss: 0.0585 - 3s/epoch - 150ms/step
# Epoch 2/500
# 21/21 - 0s - loss: 0.0389 - val_loss: 0.0279 - 129ms/epoch - 6ms/step
# Epoch 3/500
# 21/21 - 0s - loss: 0.0204 - val_loss: 0.0178 - 124ms/epoch - 6ms/step
# Epoch 4/500
# 21/21 - 0s - loss: 0.0155 - val_loss: 0.0150 - 118ms/epoch - 6ms/step
# Epoch 5/500
# 21/21 - 0s - loss: 0.0135 - val_loss: 0.0130 - 130ms/epoch - 6ms/step
# Epoch 6/500
# 21/21 - 0s - loss: 0.0116 - val_loss: 0.0111 - 137ms/epoch - 7ms/step
# Epoch 7/500
# 21/21 - 0s - loss: 0.0098 - val_loss: 0.0092 - 131ms/epoch - 6ms/step
# Epoch 8/500
# 21/21 - 0s - loss: 0.0081 - val_loss: 0.0076 - 129ms/epoch - 6ms/step
# Epoch 9/500
# 21/21 - 0s - loss: 0.0066 - val_loss: 0.0062 - 130ms/epoch - 6ms/step
# Epoch 10/500
# 21/21 - 0s - loss: 0.0054 - val_loss: 0.0051 - 124ms/epoch - 6ms/step
# Epoch 11/500
# 21/21 - 0s - loss: 0.0045 - val_loss: 0.0043 - 116ms/epoch - 6ms/step
# Epoch 12/500
# 21/21 - 0s - loss: 0.0038 - val_loss: 0.0037 - 118ms/epoch - 6ms/step
# Epoch 13/500
# 21/21 - 0s - loss: 0.0033 - val_loss: 0.0034 - 125ms/epoch - 6ms/step
# Epoch 14/500
# 21/21 - 0s - loss: 0.0031 - val_loss: 0.0031 - 112ms/epoch - 5ms/step
# Epoch 15/500
# 21/21 - 0s - loss: 0.0029 - val_loss: 0.0030 - 124ms/epoch - 6ms/step
# Epoch 16/500
# 21/21 - 0s - loss: 0.0027 - val_loss: 0.0029 - 127ms/epoch - 6ms/step
# Epoch 17/500
# 21/21 - 0s - loss: 0.0026 - val_loss: 0.0028 - 128ms/epoch - 6ms/step
# Epoch 18/500
# 21/21 - 0s - loss: 0.0025 - val_loss: 0.0027 - 125ms/epoch - 6ms/step
# Epoch 19/500
# 21/21 - 0s - loss: 0.0025 - val_loss: 0.0027 - 123ms/epoch - 6ms/step
# Epoch 20/500
# 21/21 - 0s - loss: 0.0024 - val_loss: 0.0026 - 134ms/epoch - 6ms/step
# Epoch 21/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0026 - 124ms/epoch - 6ms/step
# Epoch 22/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0025 - 127ms/epoch - 6ms/step
# Epoch 23/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0025 - 131ms/epoch - 6ms/step
# Epoch 24/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0025 - 119ms/epoch - 6ms/step
# Epoch 25/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0025 - 141ms/epoch - 7ms/step
# Epoch 26/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0024 - 131ms/epoch - 6ms/step
# Epoch 27/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0024 - 129ms/epoch - 6ms/step
# Epoch 28/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0024 - 119ms/epoch - 6ms/step
# Epoch 29/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0024 - 126ms/epoch - 6ms/step
# Epoch 30/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0024 - 124ms/epoch - 6ms/step
# Epoch 31/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0023 - 118ms/epoch - 6ms/step
# Epoch 32/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0023 - 130ms/epoch - 6ms/step
# Epoch 33/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0023 - 121ms/epoch - 6ms/step
# Epoch 34/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0023 - 116ms/epoch - 6ms/step
# Epoch 35/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0023 - 130ms/epoch - 6ms/step
# Epoch 36/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0023 - 125ms/epoch - 6ms/step
# Epoch 37/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0022 - 123ms/epoch - 6ms/step
# Epoch 38/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0022 - 118ms/epoch - 6ms/step
# Epoch 39/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0022 - 121ms/epoch - 6ms/step
# Epoch 40/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0022 - 131ms/epoch - 6ms/step
# Epoch 41/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0022 - 122ms/epoch - 6ms/step
# Epoch 42/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0021 - 121ms/epoch - 6ms/step
# Epoch 43/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0021 - 123ms/epoch - 6ms/step
# Epoch 44/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0021 - 131ms/epoch - 6ms/step
# Epoch 45/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0021 - 125ms/epoch - 6ms/step
# Epoch 46/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0021 - 124ms/epoch - 6ms/step
# Epoch 47/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0020 - 126ms/epoch - 6ms/step
# Epoch 48/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0020 - 136ms/epoch - 6ms/step
# Epoch 49/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0020 - 119ms/epoch - 6ms/step
# Epoch 50/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0020 - 120ms/epoch - 6ms/step
# Epoch 51/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0020 - 124ms/epoch - 6ms/step
# Epoch 52/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0020 - 117ms/epoch - 6ms/step
# Epoch 53/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 118ms/epoch - 6ms/step
# Epoch 54/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0019 - 128ms/epoch - 6ms/step
# Epoch 55/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0019 - 128ms/epoch - 6ms/step
# Epoch 56/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0019 - 122ms/epoch - 6ms/step
# Epoch 57/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0019 - 124ms/epoch - 6ms/step
# Epoch 58/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0019 - 128ms/epoch - 6ms/step
# Epoch 59/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 125ms/epoch - 6ms/step
# Epoch 60/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 147ms/epoch - 7ms/step
# Epoch 61/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 131ms/epoch - 6ms/step
# Epoch 62/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 130ms/epoch - 6ms/step
# Epoch 63/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 123ms/epoch - 6ms/step
# Epoch 64/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 134ms/epoch - 6ms/step
# Epoch 65/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 132ms/epoch - 6ms/step
# Epoch 66/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 122ms/epoch - 6ms/step
# Epoch 67/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 176ms/epoch - 8ms/step
# Epoch 68/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 173ms/epoch - 8ms/step
# Epoch 69/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 217ms/epoch - 10ms/step
# Epoch 70/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 187ms/epoch - 9ms/step
# Epoch 71/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 161ms/epoch - 8ms/step
# Epoch 72/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 168ms/epoch - 8ms/step
# Epoch 73/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 163ms/epoch - 8ms/step
# Epoch 74/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 179ms/epoch - 9ms/step
# Epoch 75/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 190ms/epoch - 9ms/step
# Epoch 76/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 174ms/epoch - 8ms/step
# Epoch 77/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 171ms/epoch - 8ms/step
# Epoch 78/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 179ms/epoch - 9ms/step
# Epoch 79/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 179ms/epoch - 9ms/step
# Epoch 80/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 170ms/epoch - 8ms/step
# Epoch 81/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 168ms/epoch - 8ms/step
# Epoch 82/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 182ms/epoch - 9ms/step
# Epoch 83/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 177ms/epoch - 8ms/step
# Epoch 84/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 183ms/epoch - 9ms/step
# Epoch 85/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 173ms/epoch - 8ms/step
# Epoch 86/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 122ms/epoch - 6ms/step
# Epoch 87/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 125ms/epoch - 6ms/step
# Epoch 88/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 129ms/epoch - 6ms/step
# Epoch 89/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 133ms/epoch - 6ms/step
# Epoch 90/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0016 - 128ms/epoch - 6ms/step
# Epoch 91/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 116ms/epoch - 6ms/step
# Epoch 92/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 129ms/epoch - 6ms/step
# Epoch 93/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 128ms/epoch - 6ms/step
# Epoch 94/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 132ms/epoch - 6ms/step
# Epoch 95/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 118ms/epoch - 6ms/step
# Epoch 96/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 146ms/epoch - 7ms/step
# Epoch 97/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 128ms/epoch - 6ms/step
# Epoch 98/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 132ms/epoch - 6ms/step
# Epoch 99/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 128ms/epoch - 6ms/step
# Epoch 100/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 127ms/epoch - 6ms/step
# Epoch 101/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 116ms/epoch - 6ms/step
# Epoch 102/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 118ms/epoch - 6ms/step
# Epoch 103/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 127ms/epoch - 6ms/step
# Epoch 104/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 139ms/epoch - 7ms/step
# Epoch 105/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 123ms/epoch - 6ms/step
# Epoch 106/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 132ms/epoch - 6ms/step
# Epoch 107/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 136ms/epoch - 6ms/step
# Epoch 108/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 125ms/epoch - 6ms/step
# Epoch 109/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 117ms/epoch - 6ms/step
# Epoch 110/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 121ms/epoch - 6ms/step
# Epoch 111/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 124ms/epoch - 6ms/step
# Epoch 112/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 132ms/epoch - 6ms/step
# Epoch 113/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0016 - 117ms/epoch - 6ms/step
# Epoch 114/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 115/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 116/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 117/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 113ms/epoch - 5ms/step
# Epoch 118/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 119/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 137ms/epoch - 7ms/step
# Epoch 120/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 121/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 122/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 115ms/epoch - 5ms/step
# Epoch 123/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 124/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 125/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 126/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 127/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 136ms/epoch - 6ms/step
# Epoch 128/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 137ms/epoch - 7ms/step
# Epoch 129/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 130/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 131/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 132/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 133/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 134/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 135/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 136/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 137/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 138/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 139/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 140/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 141/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 142/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 143/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 144/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 145/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 146/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 147/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 148/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 149/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 150/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 151/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 136ms/epoch - 6ms/step
# Epoch 152/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 114ms/epoch - 5ms/step
# Epoch 153/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 154/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 155/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 156/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 157/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 158/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 159/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 160/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 161/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 162/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 163/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 188ms/epoch - 9ms/step
# Epoch 164/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 171ms/epoch - 8ms/step
# Epoch 165/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 182ms/epoch - 9ms/step
# Epoch 166/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 177ms/epoch - 8ms/step
# Epoch 167/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 186ms/epoch - 9ms/step
# Epoch 168/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 177ms/epoch - 8ms/step
# Epoch 169/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 170ms/epoch - 8ms/step
# Epoch 170/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 166ms/epoch - 8ms/step
# Epoch 171/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 181ms/epoch - 9ms/step
# Epoch 172/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 171ms/epoch - 8ms/step
# Epoch 173/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 165ms/epoch - 8ms/step
# Epoch 174/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 168ms/epoch - 8ms/step
# Epoch 175/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 193ms/epoch - 9ms/step
# Epoch 176/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 167ms/epoch - 8ms/step
# Epoch 177/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 201ms/epoch - 10ms/step
# Epoch 178/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 173ms/epoch - 8ms/step
# Epoch 179/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 186ms/epoch - 9ms/step
# Epoch 180/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 187ms/epoch - 9ms/step
# Epoch 181/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 168ms/epoch - 8ms/step
# Epoch 182/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 183/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 139ms/epoch - 7ms/step
# Epoch 184/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 185/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 186/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 187/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 188/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 189/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 114ms/epoch - 5ms/step
# Epoch 190/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 191/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 136ms/epoch - 6ms/step
# Epoch 192/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 193/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 194/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 195/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 196/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 197/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 198/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 199/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 200/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 136ms/epoch - 6ms/step
# Epoch 201/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 202/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 203/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 204/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 205/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 206/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 207/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 208/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 209/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 210/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 211/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 212/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 213/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 214/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 141ms/epoch - 7ms/step
# Epoch 215/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 216/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 217/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 218/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 219/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 220/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 221/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 222/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 142ms/epoch - 7ms/step
# Epoch 223/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 224/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 225/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 226/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 227/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 228/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 229/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 230/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 231/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 232/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 233/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 234/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 137ms/epoch - 7ms/step
# Epoch 235/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 236/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 237/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 138ms/epoch - 7ms/step
# Epoch 238/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 239/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 240/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 141ms/epoch - 7ms/step
# Epoch 241/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 242/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 243/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 244/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 245/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 246/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 247/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 139ms/epoch - 7ms/step
# Epoch 248/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 249/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 144ms/epoch - 7ms/step
# Epoch 250/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 251/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 252/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 253/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 254/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 255/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 256/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 257/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 164ms/epoch - 8ms/step
# Epoch 258/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 176ms/epoch - 8ms/step
# Epoch 259/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 174ms/epoch - 8ms/step
# Epoch 260/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 171ms/epoch - 8ms/step
# Epoch 261/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 186ms/epoch - 9ms/step
# Epoch 262/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 171ms/epoch - 8ms/step
# Epoch 263/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 177ms/epoch - 8ms/step
# Epoch 264/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 173ms/epoch - 8ms/step
# Epoch 265/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 190ms/epoch - 9ms/step
# Epoch 266/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 179ms/epoch - 9ms/step
# Epoch 267/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 163ms/epoch - 8ms/step
# Epoch 268/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 211ms/epoch - 10ms/step
# Epoch 269/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 186ms/epoch - 9ms/step
# Epoch 270/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 240ms/epoch - 11ms/step
# Epoch 271/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 168ms/epoch - 8ms/step
# Epoch 272/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 178ms/epoch - 8ms/step
# Epoch 273/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 169ms/epoch - 8ms/step
# Epoch 274/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 168ms/epoch - 8ms/step
# Epoch 275/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 154ms/epoch - 7ms/step
# Epoch 276/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 277/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 278/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 279/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 280/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 113ms/epoch - 5ms/step
# Epoch 281/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 282/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 283/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 284/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 285/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 286/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 287/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 288/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 289/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 290/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 291/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 135ms/epoch - 6ms/step
# Epoch 292/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 293/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 294/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 112ms/epoch - 5ms/step
# Epoch 295/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 296/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 297/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 298/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 299/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 300/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 140ms/epoch - 7ms/step
# Epoch 301/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 302/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 115ms/epoch - 5ms/step
# Epoch 303/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 304/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 305/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 306/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 115ms/epoch - 5ms/step
# Epoch 307/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 308/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 309/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 310/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 112ms/epoch - 5ms/step
# Epoch 311/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 312/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 313/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 314/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 113ms/epoch - 5ms/step
# Epoch 315/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 316/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 317/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 318/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 319/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 320/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 113ms/epoch - 5ms/step
# Epoch 321/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 322/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 323/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 324/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 135ms/epoch - 6ms/step
# Epoch 325/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 326/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 327/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 114ms/epoch - 5ms/step
# Epoch 328/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 329/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 330/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 114ms/epoch - 5ms/step
# Epoch 331/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 332/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 333/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 334/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 335/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 336/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 337/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 338/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 339/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 340/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 341/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 342/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 112ms/epoch - 5ms/step
# Epoch 343/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 142ms/epoch - 7ms/step
# Epoch 344/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 345/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 346/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 150ms/epoch - 7ms/step
# Epoch 347/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 184ms/epoch - 9ms/step
# Epoch 348/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 170ms/epoch - 8ms/step
# Epoch 349/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 176ms/epoch - 8ms/step
# Epoch 350/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 178ms/epoch - 8ms/step
# Epoch 351/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 223ms/epoch - 11ms/step
# Epoch 352/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 222ms/epoch - 11ms/step
# Epoch 353/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 203ms/epoch - 10ms/step
# Epoch 354/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 212ms/epoch - 10ms/step
# Epoch 355/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 242ms/epoch - 12ms/step
# Epoch 356/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 203ms/epoch - 10ms/step
# Epoch 357/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 223ms/epoch - 11ms/step
# Epoch 358/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 196ms/epoch - 9ms/step
# Epoch 359/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 273ms/epoch - 13ms/step
# Epoch 360/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 236ms/epoch - 11ms/step
# Epoch 361/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 230ms/epoch - 11ms/step
# Epoch 362/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 212ms/epoch - 10ms/step
# Epoch 363/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 221ms/epoch - 11ms/step
# Epoch 364/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 232ms/epoch - 11ms/step
# Epoch 365/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 241ms/epoch - 11ms/step
# Epoch 366/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 224ms/epoch - 11ms/step
# Epoch 367/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 228ms/epoch - 11ms/step
# Epoch 368/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 271ms/epoch - 13ms/step
# Epoch 369/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 204ms/epoch - 10ms/step
# Epoch 370/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 211ms/epoch - 10ms/step
# Epoch 371/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 192ms/epoch - 9ms/step
# Epoch 372/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 181ms/epoch - 9ms/step
# Epoch 373/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 176ms/epoch - 8ms/step
# Epoch 374/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 179ms/epoch - 9ms/step
# Epoch 375/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 168ms/epoch - 8ms/step
# Epoch 376/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 377/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 378/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 379/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 380/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 381/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 382/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 383/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 384/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 385/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 386/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 387/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 139ms/epoch - 7ms/step
# Epoch 388/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 389/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 390/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 391/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 392/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 393/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 137ms/epoch - 7ms/step
# Epoch 394/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 395/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 396/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 397/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 398/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 115ms/epoch - 5ms/step
# Epoch 399/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 400/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 401/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 402/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 403/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 404/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 405/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 406/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 149ms/epoch - 7ms/step
# Epoch 407/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 126ms/epoch - 6ms/step
# Epoch 408/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 409/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 410/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 411/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 412/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 413/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 414/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 415/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 416/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 417/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 418/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 115ms/epoch - 5ms/step
# Epoch 419/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 420/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 421/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 422/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 423/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 424/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 425/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 426/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 427/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 428/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 429/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 430/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 431/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 432/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 110ms/epoch - 5ms/step
# Epoch 433/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 434/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 435/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 116ms/epoch - 6ms/step
# Epoch 436/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 437/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 438/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 120ms/epoch - 6ms/step
# Epoch 439/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 440/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 441/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 442/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 443/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 112ms/epoch - 5ms/step
# Epoch 444/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 119ms/epoch - 6ms/step
# Epoch 445/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 115ms/epoch - 5ms/step
# Epoch 446/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 447/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 448/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 449/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 450/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 451/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 452/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 131ms/epoch - 6ms/step
# Epoch 453/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 144ms/epoch - 7ms/step
# Epoch 454/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 218ms/epoch - 10ms/step
# Epoch 455/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 175ms/epoch - 8ms/step
# Epoch 456/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 484ms/epoch - 23ms/step
# Epoch 457/500
# 21/21 - 1s - loss: 0.0013 - val_loss: 0.0015 - 614ms/epoch - 29ms/step
# Epoch 458/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 421ms/epoch - 20ms/step
# Epoch 459/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 185ms/epoch - 9ms/step
# Epoch 460/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 174ms/epoch - 8ms/step
# Epoch 461/500
# 21/21 - 1s - loss: 0.0013 - val_loss: 0.0015 - 512ms/epoch - 24ms/step
# Epoch 462/500
# 21/21 - 1s - loss: 0.0013 - val_loss: 0.0015 - 555ms/epoch - 26ms/step
# Epoch 463/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 381ms/epoch - 18ms/step
# Epoch 464/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 465/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 466/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 147ms/epoch - 7ms/step
# Epoch 467/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 138ms/epoch - 7ms/step
# Epoch 468/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 469/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 470/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 471/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 472/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 117ms/epoch - 6ms/step
# Epoch 473/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 474/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 123ms/epoch - 6ms/step
# Epoch 475/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 476/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 477/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 134ms/epoch - 6ms/step
# Epoch 478/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 143ms/epoch - 7ms/step
# Epoch 479/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 480/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 124ms/epoch - 6ms/step
# Epoch 481/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 482/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 483/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 484/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 170ms/epoch - 8ms/step
# Epoch 485/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 121ms/epoch - 6ms/step
# Epoch 486/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 127ms/epoch - 6ms/step
# Epoch 487/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 488/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 113ms/epoch - 5ms/step
# Epoch 489/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 490/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step
# Epoch 491/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 118ms/epoch - 6ms/step
# Epoch 492/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 133ms/epoch - 6ms/step
# Epoch 493/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 128ms/epoch - 6ms/step
# Epoch 494/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 495/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 130ms/epoch - 6ms/step
# Epoch 496/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 122ms/epoch - 6ms/step
# Epoch 497/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 125ms/epoch - 6ms/step
# Epoch 498/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 129ms/epoch - 6ms/step
# Epoch 499/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 136ms/epoch - 6ms/step
# Epoch 500/500
# 21/21 - 0s - loss: 0.0013 - val_loss: 0.0015 - 132ms/epoch - 6ms/step

# %% [markdown]
# ## Metrics ($RAiDL$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
print('Test Phys: %.3f' % phy)
# Out:
# 11/11 [==============================] - 0s 2ms/step
# (325, 3)
# (325, 10)
# Test RMSE: 0.428
# Test MAE: 0.333
# Test Phys: 0.822

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('El Niño Surface Temperature of the Sea', fontsize=20)
plt.legend(fontsize=20)
plt.show()
